# %% [markdown]
# # KITTI Classical MPC Exploratory Analysis
#
# This notebook is reserved for dataset inspection, trajectory sanity checks, and publication figure prototyping. The production pipeline lives in `src/main.py`.
